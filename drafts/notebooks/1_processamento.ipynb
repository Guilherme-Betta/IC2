# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from utils import dados, salvar

from processamento import prep_brutos, limpeza
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pathlib import Path
#       3 sys.path.append(str(Path.cwd().parent))
# ----> 5 from utils import dados, salvar
#       7 from processamento import prep_brutos, limpeza
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Teste:

#  Carregamento do arquivo de interesse

dados_brutos = dados("data\in\dados_brutos.xlsx")

dados_brutos, metadados, variaveis = prep_brutos(dados_brutos)
salvar(dados_brutos, "brutos_prontos")

# %%
# Teste:

dados, metadados, variaveis = dados(r"data\out\brutos_prontos20260410_105610.xlsx")

limpeza(dados, metadados=metadados, variaveis=variaveis)
