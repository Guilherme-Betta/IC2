# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from utils import dados, pivot, salvar

# %%
# Dados

dados_brutos = dados(r"data\input\dados_brutos.xlsx")

dados_limpos = dados(r"data\input\dados_limpos.xlsx")

imput_mean_limpos = dados(r"data\input\imput_mean_limpos.xlsx")

imput_median_limpos = dados(r"data\input\imput_median_limpos.xlsx")

imput_knn_limpos = dados(r"data\input\imput_knn_limpos.xlsx")

imput_mean_zscore = dados(r"data\input\imput_mean_zscore.xlsx")

imput_median_zscore = dados(r"data\input\imput_median_zscore.xlsx")

imput_knn_zscore = dados(r"data\input\imput_knn_zscore.xlsx")

imput_mean_iqr = dados(r"data\input\imput_mean_iqr.xlsx")

imput_median_iqr = dados(r"data\input\imput_median_iqr.xlsx")

imput_knn_iqr = dados(r"data\input\imput_knn_iqr.xlsx")

# %% [markdown]
# # RMSE

# %%
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# # MAE

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Bias

# %%
from sklearn.metrics import

# %% [markdown]
# # r²

# %%
from sklearn.metrics import r2_score
